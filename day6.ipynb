# %%
"""
list1=list('bvwb jplb gahd k')
number of 4 character combos = len - 3
9=>6
13->10

1bvwv
2vwbj
3wbjp
4bjpl
5jplb
6plbg
7lbga
8bgah
9gahd
10ahdk
"""

list1=list('bvwbjplbgvbhsrlpgdmjqwftvncz')
list1=list('nznrnfrfntjfmvfwmzdfjlvtqnbhcprsg')
print(list1)
list2=[]
for x in range(len(list1)-3):
    list2.append(list1[x:x+4])

print(list2)
for index, x in enumerate(list2):

    if len(set(x))==4:
        print(f"{index=}")
        print(f"answer={index+4}")
        break
# Out:
# ['n', 'z', 'n', 'r', 'n', 'f', 'r', 'f', 'n', 't', 'j', 'f', 'm', 'v', 'f', 'w', 'm', 'z', 'd', 'f', 'j', 'l', 'v', 't', 'q', 'n', 'b', 'h', 'c', 'p', 'r', 's', 'g']
# [['n', 'z', 'n', 'r'], ['z', 'n', 'r', 'n'], ['n', 'r', 'n', 'f'], ['r', 'n', 'f', 'r'], ['n', 'f', 'r', 'f'], ['f', 'r', 'f', 'n'], ['r', 'f', 'n', 't'], ['f', 'n', 't', 'j'], ['n', 't', 'j', 'f'], ['t', 'j', 'f', 'm'], ['j', 'f', 'm', 'v'], ['f', 'm', 'v', 'f'], ['m', 'v', 'f', 'w'], ['v', 'f', 'w', 'm'], ['f', 'w', 'm', 'z'], ['w', 'm', 'z', 'd'], ['m', 'z', 'd', 'f'], ['z', 'd', 'f', 'j'], ['d', 'f', 'j', 'l'], ['f', 'j', 'l', 'v'], ['j', 'l', 'v', 't'], ['l', 'v', 't', 'q'], ['v', 't', 'q', 'n'], ['t', 'q', 'n', 'b'], ['q', 'n', 'b', 'h'], ['n', 'b', 'h', 'c'], ['b', 'h', 'c', 'p'], ['h', 'c', 'p', 'r'], ['c', 'p', 'r', 's'], ['p', 'r', 's', 'g']]
# index=6
# answer=10

# %%
#part 1
with open('/Users/manaskaushik/Documents/AoC2022/day6.txt', 'r') as f:
    Lines = f.readlines()
print(Lines)
list1=list(Lines[0])
print(list1)
list2=[]
for x in range(len(list1)-3):
    list2.append(list1[x:x+4])

print(list2)
for index, x in enumerate(list2):

    if len(set(x))==4:
        print(f"{index=}")
        print(f"answer={index+4}")
        break
# Out:
# ['...\n']
# ...

# %%
#part2 
with open('/Users/manaskaushik/Documents/AoC2022/day6.txt', 'r') as f:
    Lines = f.readlines()
print(Lines)
list1=list(Lines[0])
print(list1)
list2=[]
for x in range(len(list1)-13):
    list2.append(list1[x:x+14])

print(list2)
for index, x in enumerate(list2):

    if len(set(x))==14:
        print(f"{index=}")
        print(f"answer={index+14}")
        break
# Out:
# ['...\n']
# ...
